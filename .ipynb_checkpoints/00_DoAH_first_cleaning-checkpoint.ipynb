# %% [markdown]
# # Step 1
# We import the .csv file of the Database of Art Historians filtered by nationality ('it') and manually integrated with Wikidata info. Then, we create a pandas dataframe to easily store and manipulate this information.

# %%
import pandas as pd

# python3 -m pip install qwikidata
# python library for working with sparql and linked data from WikiData
from qwikidata.sparql import return_sparql_query_results

# %%
# create first dataframe only using the specified columns 
data = pd.read_csv("DoAH_StoriciItaliani_integrato.csv", sep=",",
                    usecols=["Full Name", "Gender", "Collection", "Keeper"])

# axis 0 to drop the rows, subset to only remove NaNs from the column Archives
data.dropna(axis=0, subset=["Keeper"], inplace=True)

# resetting the index because all deleted rows have changed the length of the dataframe
data.reset_index(inplace=True, drop=True)

# .pickle is a python serialization format for easy and quick read-write, and pandas supports it natively
data.to_pickle("00_first_db.pickle")

# the first table we have looks like this:
pd.set_option("display.max_rows", None)
data.head(120)
# Out:
#                              Full Name  Gender  \
# 0                     Accascina, Maria  female
# 1                   Agostini, Leonardo    male
# 2                   Alfieri, Vittorio     male
# 3                    Alinari, Giuseppe    male
# 4                    Alinari, Leopoldo    male
# 5                 Arcangeli, Francesco    male
# 6                      Aretino, Pietro    male
# 7                  Argan, Giulio Carlo    male
# 8                  Arias, Paolo Enrico    male
# 9                 Baglione, Giovanni      male
# 10                 Baldinucci, Filippo    male
# 11                  Bandinelli, Baccio    male
# 12                       Banti, Luisa   female
# 13                     Barocchi, Paola  female
# 14                  Baroni, Costantino    male
# 15                    Bellosi, Luciano    male
# 16            Bertini Calosso, Achille    male
# 17        Bianchi Bandinelli, Ranuccio    male
# 18        Bianconi, Giovanni Ludovico     male
# 19                      Billi, Antonio    male
# 20                Biondo, Michelangelo    male
# 21          Bolognini Amorini, Antonio    male
# 22                       Boni, Giacomo    male
# 23                 Borghini, Raffaello    male
# 24                    Boschini, Marco     male
# 25                     Bossi, Giuseppe    male
# 26                  Brizio, Anna Maria  female
# 27                     Brizio, Edoardo    male
# 28                    Bucarelli, Palma  female
# 29                     Calabrese, Omar    male
# 30               Calvi, Girolamo Luigi    male
# 31                   Campori, Giuseppe    male
# 32                         Carli, Enzo    male
# 33                      Carocci, Guido    male
# 34            Castiglione, Baldassarre    male
# 35                      Cecchi, Emilio    male
# 36            Cesnola, Luigi Palma di     male
# 37                 Cicognara, Leopoldo    male
# 38                      Coletti, Luigi    male
# 39                    Condivi, Ascanio    male
# 40                    Croce, Benedetto    male
# 41                     d'Ancona, Paolo    male
# 42                De Vecchi, Pierluigi    male
# 43               Di Marzo, Gioacchino     male
# 44                   Facio, Bartolomeo    male
# 45         Fagiolo dell'Arco, Maurizio    male
# 46                            Filarete    male
# 47                    Fiocco, Giuseppe    male
# 48                François, Alessandro    male
# 49                   Frizzoni, Gustavo    male
# 50                          Fea, Carlo    male
# 51   Gabburri, Francesco Maria Niccolo    male
# 52                        Gamba, Carlo    male
# 53                 Gasparini, Graziano    male
# 54                 Gelli, Giambattista    male
# 55                    Giglioli, Giulio    male
# 56     Cavalcaselle, Giovanni Battista    male
# 57                 Giovannoni, Gustavo    male
# 58                      Gnoli, Umberto    male
# 59                      Gnudi, Cesare     male
# 60             Gori, Antonio Francesco    male
# 61              Gualandi, Michelangelo    male
# 62                    Guarnacci, Mario    male
# 63              Guicciardini, Lodovico    male
# 64                   Lanciani, Rodolfo    male
# 65                 Landino, Cristoforo    male
# 66                        Lanzi, Luigi    male
# 67                      Ligorio, Pirro    male
# 68                Lomazzo, Gian Paolo     male
# 69                     Longhi, Roberto    male
# 70                  Magagnato, Licisco    male
# 71                    Maltese, Corrado    male
# 72              Malvasia, Carlo Cesare    male
# 73                     Mancini, Giulio    male
# 74             Marabottini, Alessandro    male
# 75                 Margherita Sarfatti  female
# 76                    Mariani, Valerio    male
# 77                  Milanesi, Gaetano     male
# 78                  Milizia, Francesco    male
# 79           Monneret de Villard, Ugo     male
# 80              Muraro, Michaelangelo     male
# 81                      Orsini, Fulvio    male
# 82                 Pallottino, Massimo    male
# 83                Pallucchini, Rodolfo    male
# 84                       Pane, Roberto    male
# 85                    Paribeni, Enrico    male
# 86                     Pascoli, Lione     male
# 87          Passeri, Giovanni Battista    male
# 88          Patin, Charlotte-Catherine  female
# 89                     Pedretti, Carlo    male
# 90                 Pietrangeli, Carlo     male
# 91                     Pittaluga, Mary  female
# 92                     Poggi, Giovanni    male
# 93                   Portoghesi, Paolo    male
# 94                         Praz, Mario    male
# 95                 Previtali, Giovanni    male
# 96                       Procacci, Ugo    male
# 97                         Ragusa, Isa  female
# 98                      Ricci, Corrado    male
# 99                      Ridolfi, Carlo    male
# 100                    Ridolfi, Enrico    male
# 101                     Salerno, Luigi    male
# 102                       Salmi, Mario    male
# 103                    Santi, Giovanni    male
# 104                  Selvatico, Pietro    male
# 105            Supino, Igino Benvenuto    male
# 106                 Tarchiani, Nello      male
# 107                           Tea, Eva  female
# 108                    Tucci, Giuseppe    male
# 109                   Vasari, Giorgio     male
# 110                    Venturi, Adolfo    male
# 111                  Venturi, Lionello    male
# 112                   Villani, Filippo    male
# 113          Visconti, Filippo Aurelio    male
# 114        Visconti, Giovanni Battista    male
# 115                      Volpi, Marisa  female
# 116  Zanetti, Antonio Maria Alessandro    male
# 117                     Zeri, Federico    male
# 118                        Zevi, Bruno    male
#
#                                             Collection  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                     Archivio Alinari
# 4                                     Archivio Alinari
# 5    Fondo speciale Angelo, Gaetano, Bianca e Franc...
# 6                                          Fondo Bongi
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                            Archivio Luciano Bellosi
# 16                               Fondo Bertini Calosso
# 17                   Fondo Ranuccio Bianchi Bandinelli
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                         Archivio Cincinnato Baruzzi
# 22                                    Boni-Tea Archive
# 23                                                 NaN
# 24                                                 NaN
# 25                                Fondo Giuseppe Bossi
# 26                                        Fondo Brizio
# 27                             Archivio Edoardo Brizio
# 28                               Fondo Bucarelli Palma
# 29                                Fondo Omar Calabrese
# 30                       Carte di Girolamo Luigi Calvi
# 31                     Fondo speciale Giuseppe Campori
# 32                                    Fondo Carli Enzo
# 33                                 Fondo Carocci Guido
# 34                       Archivio Pubblico Castiglioni
# 35                                 Fondo Emilio Cecchi
# 36                              Luigi Palma Collection
# 37                          Leopoldo Cicognara letters
# 38                              Fondo famiglia Coletti
# 39                               Fondo Ascanio Condivi
# 40                                                 NaN
# 41                                                 NaN
# 42                                     Fondo De Vecchi
# 43                                                 NaN
# 44                                                 NaN
# 45                                                 NaN
# 46                                                 NaN
# 47                                                 NaN
# 48                                                 NaN
# 49                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 52                                                 NaN
# 53                                                 NaN
# 54                                                 NaN
# 55                                                 NaN
# 56                                                 NaN
# 57                                                 NaN
# 58                                                 NaN
# 59                                                 NaN
# 60                                                 NaN
# 61                                                 NaN
# 62                                                 NaN
# 63                             ASR historic collection
# 64                                                 NaN
# 65                                                 NaN
# 66                                                 NaN
# 67                                                 NaN
# 68                                                 NaN
# 69                                                 NaN
# 70                                                 NaN
# 71                                                 NaN
# 72                                                 NaN
# 73                                                 NaN
# 74                                                 NaN
# 75                                                 NaN
# 76                                                 NaN
# 77                                                 NaN
# 78                                                 NaN
# 79                                                 NaN
# 80                                                 NaN
# 81                                                 NaN
# 82                            Fondo Pallottino Massimo
# 83                  Fondo librario Rodolfo Pallucchini
# 84                                     Biblioteca Pane
# 85                            Archivio Enrico Paribeni
# 86                                                 NaN
# 87                                       Fototeca Zeri
# 88                                                 NaN
# 89                                                 NaN
# 90                            Fondo Pietrangeli Carlo
# 91                                Fondo Pittaluga Mary
# 92                                Fondo Giovanni Poggi
# 93                              Fondo Paolo Portoghesi
# 94                                                 NaN
# 95                            Fondo Giovanni Previtali
# 96                                                 NaN
# 97                                                 NaN
# 98                                 Fondo Corrado Ricci
# 99                   Fondo Ridolfi di Meleto, famiglia
# 100                               Fondo Enrico Ridolfi
# 101                                                NaN
# 102                                                NaN
# 103                                                NaN
# 104                               Fondo Milanesi Carlo
# 105                     Fondo fotografico Igino Supino
# 106                              Fondo Nello Tarchiani
# 107                     Lascito Eva Tea - Giacomo Boni
# 108                Archivio fotografico Giuseppe Tucci
# 109                                    Archivio Vasari
# 110                               Fondo Adolfo Venturi
# 111                          Archivio Lionello Venturi
# 112                              Fondo Filippo Villani
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
# 117                             Federico Zeri Archives
# 118                                Archivio Bruno Zevi
#
#                                                 Keeper
# 0                                    Comune di Palermo
# 1                             Scuola Normale Superiore
# 2                       Biblioteca Medicea Laurenziana
# 3             Museo Nazionale Alinari della Fotografia
# 4             Museo Nazionale Alinari della Fotografia
# 5               Biblioteca comunale dell'Archiginnasio
# 6                              State Archives of Lucca
# 7                              Private archive in Rome
# 8                             Scuola Normale Superiore
# 9                            Archivio di Stato di Roma
# 10                National Central Library of Florence
# 11                             State Archives of Siena
# 12                              University of Florence
# 13                            Scuola Normale Superiore
# 14                            Società Storica Lombarda
# 15                                 University of Siena
# 16        Biblioteca di archeologia e storia dell'arte
# 17                             State Archives of Siena
# 18                            Getty Research Institute
# 19                National Central Library of Florence
# 20                    Bibliothèque nationale de France
# 21              Biblioteca comunale dell'Archiginnasio
# 22    Lombard Institute Academy of Science and Letters
# 23                                Fondazione Memofonte
# 24                       University Library Heidelberg
# 25                                   Ambrosian Library
# 26                                 University of Milan
# 27              Biblioteca comunale dell'Archiginnasio
# 28                       Central Archives of the State
# 29                                 University of Siena
# 30                                 University of Milan
# 31              Biblioteca comunale dell'Archiginnasio
# 32                                 University of Siena
# 33                  Biblioteca degli Uffizi di Firenze
# 34                            National Archives Mantua
# 35   Gabinetto scientifico letterario G. P. Vieusse...
# 36                          Metropolitan Museum of Art
# 37                            Getty Research Institute
# 38                                 Fondazione Benetton
# 39           Comune di Ripatransone, Ripatransone (AP)
# 40             Fondazione "Biblioteca Benedetto Croce"
# 41                            Lombardia Beni Culturali
# 42                                 University of Milan
# 43                                BEIC Digital Library
# 44                                     Lincean Academy
# 45   Galleria Nazionale d'Arte Moderna e Contemporanea
# 46                     The Nelson-Atkins Museum of Art
# 47                                BEIC Digital Library
# 48                                               JSTOR
# 49                       University Library Heidelberg
# 50                                BEIC Digital Library
# 51                                Fondazione Memofonte
# 52                             Biblioteca Marucelliana
# 53           Museo Nacional Centro de Arte Reina Sofía
# 54                                BEIC Digital Library
# 55        Biblioteca di archeologia e storia dell'arte
# 56                       Biblioteca Nazionale Marciana
# 57   Centro studi per la storia dell'architettura. ...
# 58   Galleria Nazionale d'Arte Moderna e Contemporanea
# 59                                BEIC Digital Library
# 60                                BEIC Digital Library
# 61                       Biblioteca dell'Archiginnasio
# 62                    Biblioteca Guarnacci (Volterra)
# 63    Comune di Varese. Biblioteca civica, Varese (VA)
# 64                                BEIC Digital Library
# 65                                BEIC Digital Library
# 66                          Archivio di Stato di Terni
# 67                                       Pirro Ligorio
# 68                            Ente "Raccolta vinciana"
# 69   Fondazione di studi di storia dell'arte Robert...
# 70                                Castelvecchio Museum
# 71                      Tor Vergata University of Rome
# 72                       Biblioteca Nazionale Marciana
# 73                                BEIC Digital Library
# 74            Fondazione Cassa di Risparmio di Perugia
# 75   Museum of Modern and Contemporary Art of Trent...
# 76                                 University of Udine
# 77                Biblioteca comunale degli Intronati
# 78                         Biblioteca statale di Lucca
# 79        Biblioteca di archeologia e storia dell'arte
# 80                                 University of Udine
# 81                                BEIC Digital Library
# 82                       Central Archives of the State
# 83                                 University of Udine
# 84                    University of Naples Federico II
# 85                              University of Florence
# 86                            Getty Research Institute
# 87                            Fondazione Federico Zeri
# 88                            Getty Research Institute
# 89           Nuova Fondazione Rossana e Carlo Pedretti
# 90             Sezione di Archivio di Stato di Spoleto
# 91                             Biblioteca Marucelliana
# 92   Centro di documentazione della Soprintendenza ...
# 93                         Archivio privato di Calcata
# 94                                    Museo Mario Praz
# 95                                 University of Siena
# 96                       Camaiore Religious Art Museum
# 97                   Scuola d'Italia Guglielmo Marconi
# 98   Istituto Nazionale di Archeologia e Storia del...
# 99                          Archivio privato di Meleto
# 100                        Biblioteca statale di Lucca
# 101                           Getty Research Institute
# 102  Biblioteca dell'Istituto Nazionale di Studi su...
# 103                               El Paternal Mio Nido
# 104                Biblioteca comunale degli Intronati
# 105                              Università di Bologna
# 106         Archivio contemporaneo Alessandro Bonsanti
# 107   Istituto Lombardo Accademia di Scienze e Lettere
# 108              Biblioteca Nazionale Centrale di Roma
# 109                     Casa museo Vasari, Arezzo (AR)
# 110                           Scuola Normale Superiore
# 111       Università degli Studi di Roma "La Sapienza"
# 112     Comune di Milano. Archivio civico, Milano (MI)
# 113                                   Archivi Vaticani
# 114                                     Musei Vaticani
# 115                              Archivio Marisa Volpi
# 116                      Biblioteca Nazionale Marciana
# 117                           Fondazione Federico Zeri
# 118                              Fondazione Bruno Zevi

# %% [markdown]
# # To resolve:
# 1. full names are reversed (`surname, name`)
# 2. we need to have a controlled entity (`wd:xyz`) for each name and keeper, to be able to link them to other info

# %%
def reformat_names(name):
    """ reverse names from surname,name format to name surname """
    l = name.split(", ")
    new = " ".join(reversed(l))
    return new

# %%
# reverse names and remove duplicate whitespace
data["Full Name"] = data["Full Name"].apply(reformat_names)

data.describe()
data.head()
# Out:
#            Full Name  Gender        Collection  \
# 0    Maria Accascina  female               NaN
# 1  Leonardo Agostini    male               NaN
# 2  Vittorio  Alfieri    male               NaN
# 3   Giuseppe Alinari    male  Archivio Alinari
# 4   Leopoldo Alinari    male  Archivio Alinari
#
#                                      Keeper
# 0                         Comune di Palermo
# 1                  Scuola Normale Superiore
# 2            Biblioteca Medicea Laurenziana
# 3  Museo Nazionale Alinari della Fotografia
# 4  Museo Nazionale Alinari della Fotografia

# %%
historian_entity_from_label = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT DISTINCT ?artHistorian

WHERE {{
    # ?artHistorian rdfs:label ?o
                  FILTER ( str(?o) = "{}" )  .
  
    # ?artHistorian wdt:P31 wd:Q5 ;
                  wdt:P1412 ?language
                  FILTER (?language IN (wd:Q652, wd:Q397 ) ) .
    # ?artHistorian wdt:P106 ?occupation
                  FILTER (?occupation IN (wd:Q1792450, wd:Q201788, wd:Q1622272, wd:Q3621491, wd:Q483501, wd:Q4164507, wd:Q4964182, wd:Q5697103, wd:Q33231, wd:Q1281618, wd:Q39631, wd:Q36180, wd:Q49757, wd:Q42973 ) ) .   
}}
"""

# %%
def find_historian_entity_from_name(name: str):
    query = historian_entity_from_label.format(name)
    res = return_sparql_query_results(query_string=query)
    try:
        wdt_uri = res['results']['bindings'][0]['artHistorian']['value']
    except (IndexError, KeyError):
        return ""
    return wdt_uri.split("/")[-1]

# %%
data["Historian Entity"] = data["Full Name"].apply(find_historian_entity_from_name)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19896/1861200677.py in <module>
# ----> 1 data["Historian Entity"] = data["Full Name"].apply(find_historian_entity_from_name)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\core\apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_19896/2461749701.py in find_historian_entity_from_name(name)
#       1 def find_historian_entity_from_name(name: str):
#       2     query = historian_entity_from_label.format(name)
# ----> 3     res = return_sparql_query_results(query_string=query)
#       4     try:
#       5         wdt_uri = res['results']['bindings'][0]['artHistorian']['value']
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\qwikidata\sparql.py in return_sparql_query_results(query_string, wikidata_sparql_url)
#      21     """
#      22     return requests.get(
# ---> 23         wikidata_sparql_url, params={"query": query_string, "format": "json"}
#      24     ).json()
#      25
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\requests\models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.7_3.7.2544.0_x64__qbz5n2kfra8p0\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
data.to_pickle("00_first_db.pickle")

# %%
pd.set_option("display.max_rows", None)

# %%
historian_entity_from_label_edited = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT DISTINCT ?artHistorian

WHERE {{
    OPTIONAL {{
      # ?artHistorian wdt:P1412 wd:Q652
    }}
  
    # ?artHistorian rdfs:label ?o 
                  FILTER ( str(?o) = "{}" )  .
    
  
    # ?artHistorian wdt:P31 wd:Q5 .
}}
"""

# %%
def find_remaining_entity_from_name(row):
    if row["Historian Entity"]:
        return row["Historian Entity"]
    name = row["Full Name"]
    query = historian_entity_from_label_edited.format(name)
    res = return_sparql_query_results(query_string=query)
    try:
        wdt_uri = res['results']['bindings'][0]['artHistorian']['value']
    except (IndexError, KeyError):
        return ""
    return wdt_uri.split("/")[-1]

# %%
data = pd.read_pickle("00_first_db.pickle")

data["Historian Entity"] = data[["Full Name", "Historian Entity"]].apply(find_remaining_entity_from_name, axis=1)
# Out:
# Q98804253
# Q1121086
# Q778445
# Q979574
# Q19754060
# Q1058859
# Q19753744
# Q471179
# Q18934852
# Q572091
# Q428638
# Q3617742
# Q3892735
# Q3768943
# Q1010831
# Q3055532
# Q708563
# Q2754987
# Q913963
# Q721545
# Q192348
# Q17453085
# Q19754082
# Q3852590
# Q3770555
# Q1757617
# Q1555828
# Q470377
# Q3339580
# Q19753788
# Q2019868
# Q1372695
# Q19754125
# Q19997569
# Q481474
# Q972400
# Q1361667
# Q19997557
# Q3694262
# Q1160847
# Q3769699
# Q19753755
# Q4007892
# Q323009
# Q2262449
# Q3438258
# Q962495
# Q183433
# Q16271446
# Q19753888
# Q176938
# Q981971
# Q3107317
# Q2474041
# Q3694305
# Q776990
# Q7002138
# Q6700132
# Q3849075
# Q3904250
# Q15997104
# Q59533611
# Q2824734
# Q2527217
# Q177450
# Q3849335
# Q1089074
# Q558155

# %%
data.head()
# Out:
#            Full Name  Gender        Collection  \
# 0    Maria Accascina  female               NaN
# 1  Leonardo Agostini    male               NaN
# 2  Vittorio  Alfieri    male               NaN
# 3   Giuseppe Alinari    male  Archivio Alinari
# 4   Leopoldo Alinari    male  Archivio Alinari
#
#                                      Keeper Historian Entity
# 0                       Comune di Palermo\n        Q98804253
# 1                  Scuola Normale Superiore         Q1054161
# 2            Biblioteca Medicea Laurenziana
# 3  Museo Nazionale Alinari della Fotografia
# 4  Museo Nazionale Alinari della Fotografia

# %%
# new query, to test
# just written and tested on wikidata interface, it returns 4 results for vittorio alfieri and the first is wrong
# but for some entities it works!

# the unions are all different ways to say "italy"
new_query = """
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT DISTINCT ?artHistorian

WHERE {{
  
    { ?artHistorian wdt:P27 wd:Q172579 } UNION 
    { ?artHistorian wdt:P27 wd:Q38 } UNION 
    { ?artHistorian wdt:P27 wd:Q223936 } UNION
    { ?artHistorian wdt:P27 wd:Q48742118 } UNION
    { ?artHistorian wdt:P27 wd:Q5343710 } .
  
    OPTIONAL {{
      # ?artHistorian wdt:P1412 wd:Q652
    }}
  
    # ?artHistorian rdfs:label ?o 
                  FILTER ( str(?o) = "Giuseppe Alinari" )  .
    
  
    # ?artHistorian wdt:P31 wd:Q5 .
}}

"""
